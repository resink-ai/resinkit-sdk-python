# %%
import panel as pn
pn.extension('tabulator')
pn.extension('codeeditor')

# %%
from resinkit.resinkit import Resinkit
rs = Resinkit(
    sql_gateway_url="http://localhost:8083",
)

# rs.show_vars_ui(base_url="http://localhost:8602")
rs.show_tasks_ui(base_url="http://localhost:8602")
# %%
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4dc81484-d516-4761-9421-0a70f322ef33'>
#   <div id="fe237539-895d-4c7d-90b6-9e0c23571f5f" data-root-id="4dc81484-d516-4761-9421-0a70f322ef33" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import panel as pn
pn.extension('tabulator')
pn.extension('codeeditor')

py_code = "import sys"
editor = pn.widgets.CodeEditor(value=py_code, sizing_mode='stretch_width', language='python', height=300)
editor
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='20deb71f-56c2-4eb0-b992-78e3fa4f5931'>
#   <div id="b90ffd53-2fff-4890-863f-0573991cab41" data-root-id="20deb71f-56c2-4eb0-b992-78e3fa4f5931" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
